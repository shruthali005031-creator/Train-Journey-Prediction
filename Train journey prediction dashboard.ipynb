# %%
import pandas as pd
df=pd.read_csv("Dataset1.csv")
df
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
#         Route_Number Arrival_time Departure_Time  Distance
# 0                  1     00:00:00       10:25:00         0
# 1                  1     11:06:00       11:08:00        32
# 2                  1     11:28:00       11:30:00        49
# 3                  1     12:10:00       00:00:00        78
# 4                  1     00:00:00       20:30:00         0
# ...              ...          ...            ...       ...
# 186069             1     00:00:00       06:00:00         0
# 186070             1     08:08:00       08:10:00       199
# 186071             1     09:19:00       09:21:00       312
# 186072             1     12:38:00       12:40:00       577
# 186073             1     14:00:00       00:00:00       655
#
# [186074 rows x 12 columns]

# %%
with open("dashboard.py","r")as f:
    print(f.read())
# Out:
# import streamlit as st
# import pandas as pd
#
# st.title("ðŸš† Train Journey Prediction Dashboard")
#
# st.write("### Train Journey Data")
#
# # Load dataset
# df = pd.read_csv("your_dataset.csv")
#
# st.dataframe(df.head(10))
#
# st.write("### Dataset Information")
#
# col1, col2, col3 = st.columns(3)
#
# col1.metric("Total Trains", df["Train Number"].nunique())
# col2.metric("Total Stations", df["Station Name"].nunique())
# col3.metric("Total Records", len(df))
#
# st.write("### Distance Analysis")
#
# st.bar_chart(df["Distance"].head(20))
#
# st.write("### Journey Prediction")
#
# st.write("Select a distance:")
#
# distance = st.number_input(
#     "Distance (km)",
#     min_value=0.0,
#     value=100.0
# )
#
# if st.button("Predict Journey Duration"):
#     prediction = distance / 60
#     st.success(f"Predicted Journey Duration: {prediction:.2f} hours")

# %%
import os
print("Jupyter folder:")
print(os.getcwd())

print("\nFiles here:")
print(os.listdir())
# Out:
# Jupyter folder:
# C:\Users\new
#
# Files here:
# ['.android', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.matplotlib', '.streamlit', '.vscode', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'dash.ipynb', 'dashboard.ipynb', 'dashboard.py', 'dashboard1.ipynb', 'Dataset1.csv', 'Desktop', 'dl prgrm 2.ipynb', 'Documents', 'Downloads', 'Favorites', 'IntelGraphicsProfiles', 'Journey_duration_model.pkl', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{9cf27574-bb1c-11f0-af36-f93b414aa58e}.TM.blf', 'NTUSER.DAT{9cf27574-bb1c-11f0-af36-f93b414aa58e}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{9cf27574-bb1c-11f0-af36-f93b414aa58e}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'scikit_learn_data', 'Searches', 'SendTo', 'Start Menu', 'sysslan it solutions.ipynb', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Videos']

# %%
print(os.path.abspath("dashboard.py"))
# Out:
# C:\Users\new\dashboard.py

# %%
with open(r"C:\Users\New\Dashboard.py", "w") as f:
    f.write("""import streamlit as st
import pandas as pd

st.title("Train Journey Prediction Dashboard")

df = pd.read_csv("Dataset1.csv")

st.success("Dataset loaded successfully!")

st.subheader("Dataset Preview")
st.dataframe(df.head(10))

st.subheader("Dataset Summary")

col1, col2, col3 = st.columns(3)

col1.metric("Total Records", len(df))
col2.metric("Total Stations", df["Station_Name"].nunique())
col3.metric("Total Trains", df["Train_No"].nunique())

st.subheader("Distance Analysis")
st.bar_chart(df["Distance"].head(20))

st.subheader("Journey Duration Prediction")

distance = st.number_input("Enter Distance (km)", min_value=0.0, value=100.0)

if st.button("Predict Journey Duration"):
    duration = distance / 60
    st.success("Predicted Journey Duration: {:.2f} hours".format(duration))
""")

print("Dashboard code saved!")
# Out:
# Dashboard code saved!

# %%
with open(r"C:\Users\new\dashboard.py","r")as f:
    print(f.read())
# Out:
# import streamlit as st
# import pandas as pd
#
# st.title("Train Journey Prediction Dashboard")
#
# df = pd.read_csv("Dataset1.csv")
#
# st.success("Dataset loaded successfully!")
#
# st.subheader("Dataset Preview")
# st.dataframe(df.head(10))
#
# st.subheader("Dataset Summary")
#
# col1, col2, col3 = st.columns(3)
#
# col1.metric("Total Records", len(df))
# col2.metric("Total Stations", df["Station Name"].nunique())
# col3.metric("Total Trains", df["Train Number"].nunique())
#
# st.subheader("Distance Analysis")
# st.bar_chart(df["Distance"].head(20))
#
# st.subheader("Journey Duration Prediction")
#
# distance = st.number_input("Enter Distance (km)", min_value=0.0, value=100.0)
#
# if st.button("Predict Journey Duration"):
#     duration = distance / 60
#     st.success("Predicted Journey Duration: {:.2f} hours".format(duration))

# %%
import os
print(os.path.exists(r"C:\Users\new\Dataset1.csv"))
# Out:
# True

# %%
# !streamlit run dashboard.py
